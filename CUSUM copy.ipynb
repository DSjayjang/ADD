# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir(r'C:\Users\user\Desktop\add')

# %%
# 데이터 불러오기 : gas
gas_data = pd.read_csv('GAS_v2.csv', index_col = 0)
gas_data
# Out:
#                   BD.1        BD.1.1        BD.1.2        BD.1.3  \
# 09:32:55  24213.621743  23985.363235  23966.930909  24447.283750
# 09:32:56  24207.289579  23984.207261  23977.850103  24451.743601
# 09:32:57  24216.357366  23983.975591  23970.786857  24441.452583
# 09:32:58  24204.548158  23979.118904  23968.896308  24444.173465
# 09:32:59  24221.490916  23984.720250  23963.701473  24457.858426
# ...                ...           ...           ...           ...
# 09:36:46  21982.000000  21857.000000  21856.000000  21393.000000
# 09:36:47  21894.000000  21811.000000  21779.000000  21331.000000
# 09:36:48  21598.000000  21652.000000  21700.000000  21240.000000
# 09:36:49  21529.000000  21562.000000  21536.000000  21190.000000
# 09:36:50  21457.000000  21478.000000  21454.000000  21126.000000
#
#                 BD.1.4        BD.1.5        BD.1.6        BD.1.7  \
# 09:32:55  24448.903405  24058.452911  24595.657880  24213.517250
# 09:32:56  24448.671732  24066.843195  24582.917627  24217.668143
# 09:32:57  24460.554763  24058.467287  24583.187163  24216.109287
# 09:32:58  24447.954931  24056.935314  24581.050184  24214.782910
# 09:32:59  24447.227678  24062.733710  24599.656138  24218.120705
# ...                ...           ...           ...           ...
# 09:36:46  21375.000000  21272.000000  21506.000000  21434.000000
# 09:36:47  21340.000000  21203.000000  21462.000000  21387.000000
# 09:36:48  21282.000000  21125.000000  21399.000000  21337.000000
# 09:36:49  21206.000000  20893.000000  21321.000000  21277.000000
# 09:36:50  21131.000000  20823.000000  21241.000000  21208.000000
#
#                 BD.1.8        BD.1.9  ...        BD.5.6        BD.5.7  \
# 09:32:55  24139.979260  24412.382845  ...  24684.825606  24521.412438
# 09:32:56  24131.142621  24414.093901  ...  24695.830251  24528.860739
# 09:32:57  24140.231549  24417.359744  ...  24681.695603  24526.300473
# 09:32:58  24152.488167  24403.199010  ...  24676.731434  24523.038019
# 09:32:59  24140.330296  24420.729312  ...  24681.837815  24523.507154
# ...                ...           ...  ...           ...           ...
# 09:36:46  21523.000000  21472.000000  ...  20545.000000  20662.000000
# 09:36:47  21446.000000  21400.000000  ...  20478.000000  20601.000000
# 09:36:48  21374.000000  21320.000000  ...  20490.000000  20589.000000
# 09:36:49  21301.000000  21241.000000  ...  20504.000000  20617.000000
# 09:36:50  21179.000000  21167.000000  ...  20445.000000  20567.000000
#
#                 BD.5.8        BD.5.9       BD.5.10       BD.5.11  \
# 09:32:55  24235.675634  24469.434551  24304.519401  24230.193302
# 09:32:56  24236.969881  24477.351282  24302.725532  24234.145468
# 09:32:57  24245.076938  24474.351992  24305.893913  24236.010790
# 09:32:58  24230.596355  24479.672953  24305.390337  24230.170746
# 09:32:59  24246.175014  24479.415291  24300.433991  24229.083541
# ...                ...           ...           ...           ...
# 09:36:46  21118.000000  20582.000000  20785.000000  20935.000000
# 09:36:47  21047.000000  20332.000000  20708.000000  20911.000000
# 09:36:48  21012.000000  20335.000000  20668.000000  20913.000000
# 09:36:49  21001.000000  20382.000000  20664.000000  20930.000000
# 09:36:50  20999.000000  20359.000000  20622.000000  20917.000000
#
#                BD.5.12       BD.5.13       BD.5.14       BD.5.15
# 09:32:55  24020.539125  24567.698953  24646.249740  24353.634612
# 09:32:56  24019.312291  24575.112507  24643.120631  24353.295564
# 09:32:57  24031.546210  24571.464138  24649.404807  24350.484463
# 09:32:58  24030.053507  24566.730661  24648.716754  24355.054264
# 09:32:59  24021.620093  24575.676585  24638.504103  24357.985022
# ...                ...           ...           ...           ...
# 09:36:46  21353.000000  20717.000000  21248.000000  21390.000000
# 09:36:47  21276.000000  20639.000000  21121.000000  21335.000000
# 09:36:48  21224.000000  20605.000000  21111.000000  21296.000000
# 09:36:49  21194.000000  20601.000000  21115.000000  21272.000000
# 09:36:50  21173.000000  20557.000000  21075.000000  21236.000000
#
# [236 rows x 80 columns]

# %%
# noise 추가 : 241015
gas_data1 = gas_data + np.random.normal(0, 30, size = (236, 80))
gas_data1
# Out:
#                   BD.1        BD.1.1        BD.1.2        BD.1.3  \
# 09:32:55  24228.024378  23984.509580  23963.218471  24434.774262
# 09:32:56  24190.807899  23952.606028  23989.321216  24439.210770
# 09:32:57  24233.796437  23965.508461  23971.333300  24465.300838
# 09:32:58  24194.796054  23965.392735  23989.407874  24437.319012
# 09:32:59  24192.960363  23986.003584  23978.082846  24497.506549
# ...                ...           ...           ...           ...
# 09:36:46  22003.412979  21864.117751  21823.971807  21396.495573
# 09:36:47  21874.692159  21857.618139  21864.639176  21292.258271
# 09:36:48  21563.010882  21686.124096  21697.310727  21233.054717
# 09:36:49  21512.774283  21542.752551  21575.218050  21141.438616
# 09:36:50  21453.409902  21460.827345  21469.440964  21127.616980
#
#                 BD.1.4        BD.1.5        BD.1.6        BD.1.7  \
# 09:32:55  24435.090766  24120.017712  24626.389758  24200.616123
# 09:32:56  24405.836490  24116.592476  24514.715830  24195.175294
# 09:32:57  24418.421990  24006.023820  24561.153907  24155.784461
# 09:32:58  24491.666323  24014.440122  24597.480251  24197.377962
# 09:32:59  24432.956068  24069.136844  24604.788088  24228.588117
# ...                ...           ...           ...           ...
# 09:36:46  21371.655132  21285.688434  21516.352334  21429.673074
# 09:36:47  21322.013753  21212.721838  21415.316094  21412.251982
# 09:36:48  21240.186189  21158.951661  21376.359829  21338.342014
# 09:36:49  21251.253330  20903.911895  21296.003197  21287.191764
# 09:36:50  21158.036229  20797.534565  21284.660905  21250.214697
#
#                 BD.1.8        BD.1.9  ...        BD.5.6        BD.5.7  \
# 09:32:55  24110.561688  24408.706268  ...  24702.251492  24535.320449
# 09:32:56  24131.504094  24377.880697  ...  24678.250742  24531.772403
# 09:32:57  24114.686171  24439.334007  ...  24674.895013  24541.831343
# 09:32:58  24147.310056  24413.404755  ...  24698.679442  24489.305555
# 09:32:59  24164.946503  24421.313702  ...  24699.158073  24560.350787
# ...                ...           ...  ...           ...           ...
# 09:36:46  21539.113325  21500.678974  ...  20587.186122  20706.054258
# 09:36:47  21466.221380  21375.653083  ...  20465.514520  20619.456694
# 09:36:48  21416.761418  21309.346399  ...  20447.845052  20584.280630
# 09:36:49  21317.931481  21268.292771  ...  20493.605871  20587.184926
# 09:36:50  21208.761337  21131.974829  ...  20436.917381  20574.055011
#
#                 BD.5.8        BD.5.9       BD.5.10       BD.5.11  \
# 09:32:55  24255.311871  24452.324884  24323.324934  24216.257207
# 09:32:56  24238.337346  24502.444912  24338.053152  24221.953896
# 09:32:57  24227.168785  24499.386436  24315.875950  24269.761114
# 09:32:58  24250.941323  24507.610800  24298.016437  24212.112955
# 09:32:59  24205.415277  24423.626729  24230.196648  24231.843411
# ...                ...           ...           ...           ...
# 09:36:46  21097.375515  20565.162737  20754.977574  20915.007187
# 09:36:47  21024.503374  20333.298825  20726.049626  20924.202758
# 09:36:48  21041.876676  20377.570519  20717.422479  20836.332525
# 09:36:49  20982.209899  20358.310838  20675.295262  20904.445185
# 09:36:50  21066.835439  20317.539420  20579.846222  20929.670809
#
#                BD.5.12       BD.5.13       BD.5.14       BD.5.15
# 09:32:55  24034.436343  24581.558098  24654.792878  24366.276122
# 09:32:56  24056.900722  24556.833101  24677.975055  24299.868556
# 09:32:57  24020.396364  24569.942918  24658.920471  24330.062035
# 09:32:58  23990.853141  24543.640842  24684.310747  24376.787641
# 09:32:59  23995.435484  24620.131582  24671.134826  24349.168898
# ...                ...           ...           ...           ...
# 09:36:46  21352.858537  20762.707614  21267.021309  21375.436023
# 09:36:47  21263.861790  20611.020355  21148.040600  21386.671905
# 09:36:48  21230.045223  20558.787866  21158.936669  21365.089631
# 09:36:49  21202.231487  20588.791565  21087.775659  21303.605863
# 09:36:50  21169.922599  20506.168371  21066.065987  21225.254282
#
# [236 rows x 80 columns]

# %%
plt.plot(gas_data1.iloc[:, 0])
plt.show()

# %%
gas_random = gas_data1.loc[:, ['BD.1.4','BD.2.9','BD.3.15','BD.2.4']]
gas_random
# Out:
#                 BD.1.4        BD.2.9       BD.3.15        BD.2.4
# 09:32:55  24435.090766  24635.783327  24421.246036  24794.068470
# 09:32:56  24405.836490  24587.733244  24515.825987  24712.091836
# 09:32:57  24418.421990  24637.623503  24481.333616  24764.760967
# 09:32:58  24491.666323  24558.058760  24412.022814  24717.356480
# 09:32:59  24432.956068  24612.488214  24558.362355  24751.609149
# ...                ...           ...           ...           ...
# 09:36:46  21371.655132  21050.867283  20771.385294  21045.995932
# 09:36:47  21322.013753  21120.908726  20674.833984  21023.700957
# 09:36:48  21240.186189  21102.754860  20720.049194  21061.456203
# 09:36:49  21251.253330  21064.438321  20817.965450  20993.624953
# 09:36:50  21158.036229  20968.143004  20723.402272  20928.384310
#
# [236 rows x 4 columns]

# %%
# random_col = numpy.random.randint(0, gas_data1.shape[1], size = 4)

# gas_random = gas_data1.iloc[:, random_col]
# gas_random

# %%
time_labels = gas_data1.index
time_labels
# Out:
# Index(['09:32:55', '09:32:56', '09:32:57', '09:32:58', '09:32:59', '09:33:00',
#        '09:33:01', '09:33:02', '09:33:03', '09:33:04',
#        ...
#        '09:36:41', '09:36:42', '09:36:43', '09:36:44', '09:36:45', '09:36:46',
#        '09:36:47', '09:36:48', '09:36:49', '09:36:50'],
#       dtype='object', length=236)

# %%
# 우선 univariate에 대해서만.
h = 10
phase1_len = 100

phase1_data = gas_random.values[range(0, phase1_len), 0]
phase2_data = gas_random.values[range(phase1_len, gas_random.shape[0]), 0]

# %%
class uniCUSUM:
    def __init__(self, phase1_len = 100, delta = 0.5, h = 5):
        self.delta = float(delta)
        self.h = float(h)
        self.phase1_len = phase1_len

        self.s_prev_pos_ = 0.0
        self.s_prev_neg_ = 0.0

        self.mu0_ = None
        self.sigma_ = None
        
        # self.s_pos_history = []
        # self.s_neg_history = []

    def fit(self, X: np.array):
        # phase 1
        self.phase1_data = X[:self.phase1_len]
        self.mu0_ = np.mean(self.phase1_data)
        self.sigma_ = np.std(self.phase1_data, ddof = 1)

    def update(self, x_t):
        # phase 2
        s_t_pos = max(0.0, self.s_prev_pos_ + (x_t - self.mu0_ - self.delta/2) / self.sigma_)
        s_t_neg = max(0.0, self.s_prev_neg_ + (self.mu0_ - x_t - self.delta/2) / self.sigma_)

        # 벡터 누적합 업데이트
        self.s_prev_pos_ = s_t_pos
        self.s_prev_neg_ = s_t_neg

        return s_t_pos, s_t_neg
    
    def reset(self):
        # 벡터 누적합 리셋
        self.s_prev_pos_ = 0.0
        self.s_prev_neg_ = 0.0

    # def plot(self, time_labels=None):
    #     """누적 통계량 시각화"""
    #     plt.figure(figsize=(12, 5))

    #     x = np.arange(len(self.s_pos_history))
    #     if time_labels is not None and len(time_labels) == len(x):
    #         x = time_labels

    #     plt.plot(x, self.s_pos_history, label='CUSUM Positive', color='blue')
    #     plt.plot(x, self.s_neg_history, label='CUSUM Negative', color='red')
    #     plt.axhline(self.h, color='black', linestyle='--', label='Control Limit (+h)')
    #     plt.axhline(-self.h, color='gray', linestyle='--', label='Control Limit (-h)')

    #     plt.title("CUSUM Control Chart")
    #     plt.xlabel("Time" if time_labels is not None else "Index")
    #     plt.ylabel("CUSUM Statistic")
    #     plt.legend()
    #     plt.grid(True)
    #     plt.tight_layout()
    #     plt.show()

# %%
start = []
violoation_lower, violoation_upper = [], []

cusum = uniCUSUM(phase1_len)
cusum.fit(phase1_data)

for idx, x in enumerate(phase2_data):
    s_p, s_n = cusum.update(x)

    if s_p > h:
        start_idx = phase1_len + idx
        violoation_upper.append(start_idx)
        cusum.reset()

    if s_n > h:
        start_idx = phase1_len + idx
        violoation_lower.append(start_idx)
        cusum.reset()

start_point = min(violoation_lower + violoation_upper)
print(start_point)
print(time_labels[start_point])
# Out:
# 103
# 09:34:38
